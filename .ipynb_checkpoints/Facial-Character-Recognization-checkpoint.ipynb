# %% [markdown]
# # 1. Import All Required Packages

# %%
# Import libraries# Impor 
import os,cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from pylab import rcParams
rcParams['figure.figsize'] = 20, 10
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tqdm import notebook
import keras
from sklearn import preprocessing
from keras.utils import np_utils
from keras.applications.imagenet_utils import preprocess_input
from keras import backend as K
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from tensorflow.keras.optimizers import SGD,RMSprop,Adam
from keras.preprocessing.image import ImageDataGenerator

# %%
data = pd.read_excel('DATAMATRIXKDEF.xls')
data=data.drop('Unnamed: 8',axis=1)
data
# Out:
#     KDEF code Target emotion Most rated emotion   \
# 0    M11AF           Fearful             Fearful
# 1    M25AF           Fearful             Fearful
# 2    M14AF           Fearful             Fearful
# 3    M17AF           Fearful             Fearful
# 4    M19AF           Fearful             Fearful
# ..        ...            ...                 ...
# 485  M26AF           Fearful           Surprised
# 486  F19AF           Fearful           Surprised
# 487  F15AF           Fearful           Surprised
# 488  F35AF           Fearful           Surprised
# 489  M34HA             Happy           Surprised
#
#      Percentage (biased) hit rate  Mean intensity  SD intensity  Mean arousal  \
# 0                       84.375000        5.625000      1.430950      3.671875
# 1                       84.126984        5.444444      1.653713      3.539683
# 2                       79.687500        6.484375      1.458333      4.312500
# 3                       78.125000        6.671875      1.403563      4.140625
# 4                       78.125000        7.546875      1.413424      4.619048
# ..                            ...             ...           ...           ...
# 485                     19.047619        3.933333      1.867353      3.049180
# 486                     15.625000        6.671875      1.633525      3.888889
# 487                      9.375000        4.950820      1.764712      3.387097
# 488                      9.375000        4.875000      1.685607      3.296875
# 489                      0.000000        5.703125      1.668377      3.333333
#
#      SD arousal Most rated non-target emotion(s)  \
# 0      1.480612                              Sad
# 1      1.847626                        Disgusted
# 2      1.958903                        Surprised
# 3      1.876058                            Angry
# 4      2.113158                        Surprised
# ..          ...                              ...
# 485    1.774131                        Surprised
# 486    1.960177                        Surprised
# 487    1.749518                        Surprised
# 488    1.696679                        Surprised
# 489    1.778002                        Surprised
#
#      Percentage most rated non-target emotion(s)
# 0                                       6.250000
# 1                                       7.936508
# 2                                      18.750000
# 3                                      14.062500
# 4                                      14.062500
# ..                                           ...
# 485                                    26.984127
# 486                                    73.437500
# 487                                    43.750000
# 488                                    67.187500
# 489                                    82.812500
#
# [490 rows x 10 columns]

# %% [markdown]
# # 2.Read Images from the data path

# %%
class DataLoader():
  def __init__(self, path,data):
    self.path = path
    self.data = data
  
  def preprocessing(self,instancePath):
    image = load_img(instancePath, target_size=(128, 128))
    image = img_to_array(image)
    image /= 255.0
    image = image.reshape((image.shape[0], image.shape[1], image.shape[2]))
    image = preprocess_input(image)
    return image

  def prepare_train_data(self):
    X_train = []
    y_train = []

    for i in notebook.tqdm(range(data.shape[0])):
        
        imgpath = os.path.join(self.path,self.data['KDEF code'][i].strip()+'.jpg')
        img = self.preprocessing(imgpath)
        X_train.append(img)
        y_train.append(self.data['Target emotion'][i])

    X_train = np.asarray(X_train)
    y_train = np.asarray(y_train)
    
    le = preprocessing.LabelEncoder()
    y_train = le.fit_transform(y_train)
    print(np.unique(y_train))   

    print(f'X_train shape:{X_train.shape}\nY_train shape:{y_train.shape}')
    return X_train,y_train

# %%
X_train = []
y_train = []
dl = DataLoader(path = 'KDEF/',data=data)
X_data, y_train = dl.prepare_train_data()
# Out:
#   0%|          | 0/490 [00:00<?, ?it/s]
# [0 1 2 3 4 5 6]
# X_train shape:(490, 128, 128, 3)
# Y_train shape:(490,)

# %% [markdown]
# #Define Datapath
# data_path = './KDEF/'
# data_dir_list = os.listdir(data_path)
#
# img_rows=256
# img_cols=256
# num_channel=1
#
# num_epoch=10
#
# img_data_list=[]
#
#
# for dataset in data_dir_list:
#     img_list=os.listdir(data_path+'/'+ dataset)
#     print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
#     for img in img_list:
#         input_img=cv2.imread(data_path + '/'+ dataset + '/'+ img )
#         #input_img=cv2.cvtColor(input_img, cv2.COLOR_BGR2GRAY)
#         input_img_resize=cv2.resize(input_img,(128,128))
#         img_data_list.append(input_img_resize)
#
# img_data = np.array(img_data_list)
# img_data = img_data.astype('float32')
# img_data = img_data/255
# img_data.shape

# %% [markdown]
# # 3.Define the number of classes

# %% [markdown]
# num_classes = 7
#
# num_of_samples = img_data.shape[0]
# labels = np.ones((num_of_samples,),dtype='int64')
#
# labels[0:29]=0 #30
# labels[30:59]=1 #29
# labels[60:92]=2 #32
# labels[93:124]=3 #31
# labels[125:155]=4 #30
# labels[156:187]=5 #31
# labels[188:]=6 #30
#
# names = ['ANGRY','DISGUST','FEAR','HAPPY','NEUTRAL','SAD','SURPRISE']
#
# def getLabel(id):
#     return ['ANGRY','DISGUST','FEAR','HAPPY','NEUTRAL','SAD','SURPRISE'][id]

# %%
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train, 7)
print(f'X_train shape:{X_train.shape}\nY_train shape:{Y_train.shape}')
# Out:
# X_train shape:(490, 128, 128, 3)
# Y_train shape:(490, 7)

# %% [markdown]
# # 4.Convert the class label to one-hot encoding

# %%
# convert class labels to on-hot encoding# conve 
#Y = np_utils.to_categorical(labels, num_classes)

#Shuffle the dataset
x,y = shuffle(X_data,Y_train, random_state=2)
# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.15, random_state=2)

# %% [markdown]
# # 5. CNN Layer Set

# %%
# Defining the model

input_shape=X_data[0].shape

model = Sequential()

# Feature Extraction
# model.add(Convolution2D(32,3,3, border_mode='same',input_shape=input_shape))
# model.add(Activation('relu'))
# model.add(Convolution2D(32, 3, 3))
# model.add(Activation('relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.5))

# model.add(Convolution2D(64, 3, 3))
# model.add(Activation('relu'))
# # model.add(Convolution2D(64, 3, 3))
# # model.add(Activation('relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.5))

# model.add(Convolution2D(128, 3, 3))
# model.add(Activation('relu'))
# # model.add(Convolution2D(128, 3, 3))
# # model.add(Activation('relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.5))

#new Code
model.add(Convolution2D(6, 5, 5, input_shape=input_shape, padding="same"))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Convolution2D(16, 5, 5, padding="same"))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Convolution2D(120, 5, 5,padding="same"))
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(84))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(7))
model.add(Activation('softmax'))

# Classification
# model.add(Flatten())
# model.add(Dense(64))
# model.add(Activation('relu'))
# model.add(Dropout(0.5))
# model.add(Dense(num_classes))
# model.add(Activation('softmax'))

#Compile Model
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=["accuracy"])

# %% [markdown]
# # 6.View Model Confifuration

# %%
model.summary()
model.get_config()
model.layers[0].get_config()
model.layers[0].input_shape
model.layers[0].output_shape
model.layers[0].get_weights()
np.shape(model.layers[0].get_weights()[0])
model.layers[0].trainable
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 26, 26, 6)         456
# _________________________________________________________________
# activation_10 (Activation)   (None, 26, 26, 6)         0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 13, 13, 6)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 3, 3, 16)          2416
# _________________________________________________________________
# activation_11 (Activation)   (None, 3, 3, 16)          0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 1, 1, 16)          0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 1, 1, 120)         48120
# _________________________________________________________________
# activation_12 (Activation)   (None, 1, 1, 120)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 1, 120)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 120)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# activation_13 (Activation)   (None, 84)                0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 84)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 595
# _________________________________________________________________
# activation_14 (Activation)   (None, 7)                 0
# =================================================================
# Total params: 61,751
# Trainable params: 61,751
# Non-trainable params: 0
# _________________________________________________________________
# True

# %%
from keras import callbacks
filename='model_train_new.csv'
filepath="Best-weights-my_model-{epoch:03d}-{loss:.4f}-{acc:.4f}.hdf5"

csv_log=callbacks.CSVLogger(filename, separator=',', append=False)
checkpoint = callbacks.ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [csv_log,checkpoint]
callbacks_list = [csv_log]

# %% [markdown]
# # 7. Train Model

# %%
# Training
hist = model.fit(X_train, y_train, batch_size=7, epochs=300, verbose=1, validation_data=(X_test, y_test),callbacks=callbacks_list)
# Out:
# Epoch 1/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9458 - accuracy: 0.1466 - val_loss: 1.9602 - val_accuracy: 0.0946
# Epoch 2/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9443 - accuracy: 0.1442 - val_loss: 1.9610 - val_accuracy: 0.0946
# Epoch 3/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1394 - val_loss: 1.9613 - val_accuracy: 0.0946
# Epoch 4/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9447 - accuracy: 0.1394 - val_loss: 1.9627 - val_accuracy: 0.0946
# Epoch 5/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9447 - accuracy: 0.1466 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 6/300
# 60/60 [==============================] - ETA: 0s - loss: 1.9449 - accuracy: 0.15 - 0s 5ms/step - loss: 1.9452 - accuracy: 0.1514 - val_loss: 1.9626 - val_accuracy: 0.0946
# Epoch 7/300
# 60/60 [==============================] - 0s 6ms/step - loss: 1.9449 - accuracy: 0.1538 - val_loss: 1.9624 - val_accuracy: 0.0946
# Epoch 8/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9454 - accuracy: 0.1442 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 9/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1707 - val_loss: 1.9628 - val_accuracy: 0.0946
# Epoch 10/300
# 60/60 [==============================] - 0s 6ms/step - loss: 1.9457 - accuracy: 0.1370 - val_loss: 1.9617 - val_accuracy: 0.0946
# Epoch 11/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9451 - accuracy: 0.1274 - val_loss: 1.9613 - val_accuracy: 0.0946
# Epoch 12/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9453 - accuracy: 0.1442 - val_loss: 1.9620 - val_accuracy: 0.0946
# Epoch 13/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9454 - accuracy: 0.1394 - val_loss: 1.9621 - val_accuracy: 0.0946
# Epoch 14/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9453 - accuracy: 0.1442 - val_loss: 1.9620 - val_accuracy: 0.0946
# Epoch 15/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9454 - accuracy: 0.1466 - val_loss: 1.9618 - val_accuracy: 0.0946
# Epoch 16/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9447 - accuracy: 0.1514 - val_loss: 1.9619 - val_accuracy: 0.0946
# Epoch 17/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9451 - accuracy: 0.1442 - val_loss: 1.9617 - val_accuracy: 0.0946
# Epoch 18/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9451 - accuracy: 0.1514 - val_loss: 1.9618 - val_accuracy: 0.0946
# Epoch 19/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9451 - accuracy: 0.1466 - val_loss: 1.9620 - val_accuracy: 0.0946
# Epoch 20/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1394 - val_loss: 1.9621 - val_accuracy: 0.0946
# Epoch 21/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9453 - accuracy: 0.1514 - val_loss: 1.9615 - val_accuracy: 0.0946
# Epoch 22/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9457 - accuracy: 0.1394 - val_loss: 1.9614 - val_accuracy: 0.0946
# Epoch 23/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9452 - accuracy: 0.1514 - val_loss: 1.9619 - val_accuracy: 0.0946
# Epoch 24/300
# 60/60 [==============================] - ETA: 0s - loss: 1.9449 - accuracy: 0.14 - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1442 - val_loss: 1.9613 - val_accuracy: 0.0946
# Epoch 25/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9451 - accuracy: 0.1538 - val_loss: 1.9604 - val_accuracy: 0.0946
# Epoch 26/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1394 - val_loss: 1.9605 - val_accuracy: 0.0946
# Epoch 27/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1346 - val_loss: 1.9609 - val_accuracy: 0.1081
# Epoch 28/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9453 - accuracy: 0.1659 - val_loss: 1.9610 - val_accuracy: 0.0946
# Epoch 29/300
# 60/60 [==============================] - ETA: 0s - loss: 1.9448 - accuracy: 0.15 - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9612 - val_accuracy: 0.0946
# Epoch 30/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1490 - val_loss: 1.9606 - val_accuracy: 0.0946
# Epoch 31/300
# 60/60 [==============================] - 0s 6ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9614 - val_accuracy: 0.0946
# Epoch 32/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9611 - val_accuracy: 0.0946
# Epoch 33/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9447 - accuracy: 0.1514 - val_loss: 1.9614 - val_accuracy: 0.0946
# Epoch 34/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9451 - accuracy: 0.1514 - val_loss: 1.9614 - val_accuracy: 0.0946
# Epoch 35/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9452 - accuracy: 0.1514 - val_loss: 1.9609 - val_accuracy: 0.0946
# Epoch 36/300
# 60/60 [==============================] - ETA: 0s - loss: 1.9440 - accuracy: 0.13 - 0s 5ms/step - loss: 1.9454 - accuracy: 0.1418 - val_loss: 1.9611 - val_accuracy: 0.0946
# Epoch 37/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9609 - val_accuracy: 0.0946
# Epoch 38/300
# 60/60 [==============================] - 0s 6ms/step - loss: 1.9448 - accuracy: 0.1394 - val_loss: 1.9613 - val_accuracy: 0.0946
# Epoch 39/300
# 60/60 [==============================] - 0s 6ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9616 - val_accuracy: 0.0946
# Epoch 40/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1346 - val_loss: 1.9614 - val_accuracy: 0.0946
# Epoch 41/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9617 - val_accuracy: 0.0946
# Epoch 42/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9451 - accuracy: 0.1514 - val_loss: 1.9619 - val_accuracy: 0.0946
# Epoch 43/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9451 - accuracy: 0.1514 - val_loss: 1.9615 - val_accuracy: 0.0946
# Epoch 44/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9452 - accuracy: 0.1514 - val_loss: 1.9613 - val_accuracy: 0.0946
# Epoch 45/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9612 - val_accuracy: 0.0946
# Epoch 46/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9617 - val_accuracy: 0.0946
# Epoch 47/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9615 - val_accuracy: 0.0946
# Epoch 48/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9610 - val_accuracy: 0.0946
# Epoch 49/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9612 - val_accuracy: 0.0946
# Epoch 50/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9451 - accuracy: 0.1514 - val_loss: 1.9619 - val_accuracy: 0.0946
# Epoch 51/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9612 - val_accuracy: 0.0946
# Epoch 52/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9613 - val_accuracy: 0.0946
# Epoch 53/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9617 - val_accuracy: 0.0946
# Epoch 54/300
# 60/60 [==============================] - ETA: 0s - loss: 1.9449 - accuracy: 0.15 - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9615 - val_accuracy: 0.0946
# Epoch 55/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9616 - val_accuracy: 0.0946
# Epoch 56/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9615 - val_accuracy: 0.0946
# Epoch 57/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9615 - val_accuracy: 0.0946
# Epoch 58/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9614 - val_accuracy: 0.0946
# Epoch 59/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9616 - val_accuracy: 0.0946
# Epoch 60/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9615 - val_accuracy: 0.0946
# Epoch 61/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9620 - val_accuracy: 0.0946
# Epoch 62/300
# 60/60 [==============================] - ETA: 0s - loss: 1.9451 - accuracy: 0.15 - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9616 - val_accuracy: 0.0946
# Epoch 63/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9619 - val_accuracy: 0.0946
# Epoch 64/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9619 - val_accuracy: 0.0946
# Epoch 65/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9617 - val_accuracy: 0.0946
# Epoch 66/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9614 - val_accuracy: 0.0946
# Epoch 67/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9624 - val_accuracy: 0.0946
# Epoch 68/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9622 - val_accuracy: 0.0946
# Epoch 69/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9622 - val_accuracy: 0.0946
# Epoch 70/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9622 - val_accuracy: 0.0946
# Epoch 71/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9620 - val_accuracy: 0.0946
# Epoch 72/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 73/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9617 - val_accuracy: 0.0946
# Epoch 74/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9622 - val_accuracy: 0.0946
# Epoch 75/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9622 - val_accuracy: 0.0946
# Epoch 76/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9624 - val_accuracy: 0.0946
# Epoch 77/300
# 60/60 [==============================] - 0s 6ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9621 - val_accuracy: 0.0946
# Epoch 78/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9617 - val_accuracy: 0.0946
# Epoch 79/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9621 - val_accuracy: 0.0946
# Epoch 80/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9617 - val_accuracy: 0.0946
# Epoch 81/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 82/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9622 - val_accuracy: 0.0946
# Epoch 83/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 84/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 85/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9621 - val_accuracy: 0.0946
# Epoch 86/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 87/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 88/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9624 - val_accuracy: 0.0946
# Epoch 89/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9627 - val_accuracy: 0.0946
# Epoch 90/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 91/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 92/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 93/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9626 - val_accuracy: 0.0946
# Epoch 94/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9620 - val_accuracy: 0.0946
# Epoch 95/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9620 - val_accuracy: 0.0946
# Epoch 96/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9626 - val_accuracy: 0.0946
# Epoch 97/300
# 60/60 [==============================] - 0s 6ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9627 - val_accuracy: 0.0946
# Epoch 98/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 99/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 100/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9616 - val_accuracy: 0.0946
# Epoch 101/300
# 60/60 [==============================] - 0s 6ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9624 - val_accuracy: 0.0946
# Epoch 102/300
# 60/60 [==============================] - 0s 6ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9622 - val_accuracy: 0.0946
# Epoch 103/300
# 60/60 [==============================] - 0s 7ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9621 - val_accuracy: 0.0946
# Epoch 104/300
# 60/60 [==============================] - ETA: 0s - loss: 1.9453 - accuracy: 0.16 - 0s 6ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9622 - val_accuracy: 0.0946
# Epoch 105/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 106/300
# 60/60 [==============================] - 0s 6ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9619 - val_accuracy: 0.0946
# Epoch 107/300
# 60/60 [==============================] - 0s 6ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9622 - val_accuracy: 0.0946
# Epoch 108/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9621 - val_accuracy: 0.0946
# Epoch 109/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 110/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 111/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9624 - val_accuracy: 0.0946
# Epoch 112/300
# 60/60 [==============================] - 0s 6ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9626 - val_accuracy: 0.0946
# Epoch 113/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 114/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 115/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9622 - val_accuracy: 0.0946
# Epoch 116/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 117/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9621 - val_accuracy: 0.0946
# Epoch 118/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9624 - val_accuracy: 0.0946
# Epoch 119/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9626 - val_accuracy: 0.0946
# Epoch 120/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 121/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9628 - val_accuracy: 0.0946
# Epoch 122/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9627 - val_accuracy: 0.0946
# Epoch 123/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9452 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 124/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9628 - val_accuracy: 0.0946
# Epoch 125/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9630 - val_accuracy: 0.0946
# Epoch 126/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9628 - val_accuracy: 0.0946
# Epoch 127/300
# 60/60 [==============================] - ETA: 0s - loss: 1.9435 - accuracy: 0.16 - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9629 - val_accuracy: 0.0946
# Epoch 128/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9629 - val_accuracy: 0.0946
# Epoch 129/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9629 - val_accuracy: 0.0946
# Epoch 130/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9619 - val_accuracy: 0.0946
# Epoch 131/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 132/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9622 - val_accuracy: 0.0946
# Epoch 133/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9451 - accuracy: 0.1514 - val_loss: 1.9618 - val_accuracy: 0.0946
# Epoch 134/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9617 - val_accuracy: 0.0946
# Epoch 135/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9621 - val_accuracy: 0.0946
# Epoch 136/300
# 60/60 [==============================] - ETA: 0s - loss: 1.9454 - accuracy: 0.16 - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9620 - val_accuracy: 0.0946
# Epoch 137/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9624 - val_accuracy: 0.0946
# Epoch 138/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9620 - val_accuracy: 0.0946
# Epoch 139/300
# 60/60 [==============================] - 0s 6ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 140/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9451 - accuracy: 0.1514 - val_loss: 1.9616 - val_accuracy: 0.0946
# Epoch 141/300
# 60/60 [==============================] - 0s 7ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9615 - val_accuracy: 0.0946
# Epoch 142/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 143/300
# 60/60 [==============================] - 0s 6ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 144/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 145/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1298 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 146/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9622 - val_accuracy: 0.0946
# Epoch 147/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9619 - val_accuracy: 0.0946
# Epoch 148/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 149/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9621 - val_accuracy: 0.0946
# Epoch 150/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9451 - accuracy: 0.1514 - val_loss: 1.9618 - val_accuracy: 0.0946
# Epoch 151/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9616 - val_accuracy: 0.0946
# Epoch 152/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 153/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9620 - val_accuracy: 0.0946
# Epoch 154/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9620 - val_accuracy: 0.0946
# Epoch 155/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9617 - val_accuracy: 0.0946
# Epoch 156/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 157/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9617 - val_accuracy: 0.0946
# Epoch 158/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1226 - val_loss: 1.9621 - val_accuracy: 0.0946
# Epoch 159/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 160/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9622 - val_accuracy: 0.0946
# Epoch 161/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9620 - val_accuracy: 0.0946
# Epoch 162/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9621 - val_accuracy: 0.0946
# Epoch 163/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9619 - val_accuracy: 0.0946
# Epoch 164/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 165/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9624 - val_accuracy: 0.0946
# Epoch 166/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9621 - val_accuracy: 0.0946
# Epoch 167/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 168/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9626 - val_accuracy: 0.0946
# Epoch 169/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 170/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9629 - val_accuracy: 0.0946
# Epoch 171/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9627 - val_accuracy: 0.0946
# Epoch 172/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9624 - val_accuracy: 0.0946
# Epoch 173/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9626 - val_accuracy: 0.0946
# Epoch 174/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9620 - val_accuracy: 0.0946
# Epoch 175/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1442 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 176/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9624 - val_accuracy: 0.0946
# Epoch 177/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9622 - val_accuracy: 0.0946
# Epoch 178/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9626 - val_accuracy: 0.0946
# Epoch 179/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9621 - val_accuracy: 0.0946
# Epoch 180/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9624 - val_accuracy: 0.0946
# Epoch 181/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9626 - val_accuracy: 0.0946
# Epoch 182/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 183/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9627 - val_accuracy: 0.0946
# Epoch 184/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 185/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9632 - val_accuracy: 0.0946
# Epoch 186/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9628 - val_accuracy: 0.0946
# Epoch 187/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9634 - val_accuracy: 0.0946
# Epoch 188/300
# 60/60 [==============================] - ETA: 0s - loss: 1.9425 - accuracy: 0.15 - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9633 - val_accuracy: 0.0946
# Epoch 189/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9630 - val_accuracy: 0.0946
# Epoch 190/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9637 - val_accuracy: 0.0946
# Epoch 191/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9633 - val_accuracy: 0.0946
# Epoch 192/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9629 - val_accuracy: 0.0946
# Epoch 193/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9630 - val_accuracy: 0.0946
# Epoch 194/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9628 - val_accuracy: 0.0946
# Epoch 195/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9627 - val_accuracy: 0.0946
# Epoch 196/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9631 - val_accuracy: 0.0946
# Epoch 197/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9630 - val_accuracy: 0.0946
# Epoch 198/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9630 - val_accuracy: 0.0946
# Epoch 199/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9628 - val_accuracy: 0.0946
# Epoch 200/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9629 - val_accuracy: 0.0946
# Epoch 201/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9628 - val_accuracy: 0.0946
# Epoch 202/300
# 60/60 [==============================] - 0s 6ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9626 - val_accuracy: 0.0946
# Epoch 203/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9451 - accuracy: 0.1514 - val_loss: 1.9622 - val_accuracy: 0.0946
# Epoch 204/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9629 - val_accuracy: 0.0946
# Epoch 205/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9628 - val_accuracy: 0.0946
# Epoch 206/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1346 - val_loss: 1.9624 - val_accuracy: 0.0946
# Epoch 207/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 208/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9629 - val_accuracy: 0.0946
# Epoch 209/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 210/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9624 - val_accuracy: 0.0946
# Epoch 211/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 212/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9627 - val_accuracy: 0.0946
# Epoch 213/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9626 - val_accuracy: 0.0946
# Epoch 214/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 215/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9624 - val_accuracy: 0.0946
# Epoch 216/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 217/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9629 - val_accuracy: 0.0946
# Epoch 218/300
# 60/60 [==============================] - 0s 6ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 219/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9626 - val_accuracy: 0.0946
# Epoch 220/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9628 - val_accuracy: 0.0946
# Epoch 221/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9627 - val_accuracy: 0.0946
# Epoch 222/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9628 - val_accuracy: 0.0946
# Epoch 223/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9629 - val_accuracy: 0.0946
# Epoch 224/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9626 - val_accuracy: 0.0946
# Epoch 225/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 226/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9629 - val_accuracy: 0.0946
# Epoch 227/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9622 - val_accuracy: 0.0946
# Epoch 228/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 229/300
# 60/60 [==============================] - ETA: 0s - loss: 1.9443 - accuracy: 0.14 - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9628 - val_accuracy: 0.0946
# Epoch 230/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9632 - val_accuracy: 0.0946
# Epoch 231/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9626 - val_accuracy: 0.0946
# Epoch 232/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9627 - val_accuracy: 0.0946
# Epoch 233/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9628 - val_accuracy: 0.0946
# Epoch 234/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 235/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 236/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 237/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 238/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 239/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 240/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9624 - val_accuracy: 0.0946
# Epoch 241/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9622 - val_accuracy: 0.0946
# Epoch 242/300
# 60/60 [==============================] - 0s 6ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9622 - val_accuracy: 0.0946
# Epoch 243/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 244/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9624 - val_accuracy: 0.0946
# Epoch 245/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9621 - val_accuracy: 0.0946
# Epoch 246/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9622 - val_accuracy: 0.0946
# Epoch 247/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 248/300
# 60/60 [==============================] - 0s 6ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9621 - val_accuracy: 0.0946
# Epoch 249/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9621 - val_accuracy: 0.0946
# Epoch 250/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 251/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9632 - val_accuracy: 0.0946
# Epoch 252/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9621 - val_accuracy: 0.0946
# Epoch 253/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 254/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9628 - val_accuracy: 0.0946
# Epoch 255/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9620 - val_accuracy: 0.0946
# Epoch 256/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 257/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9622 - val_accuracy: 0.0946
# Epoch 258/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9621 - val_accuracy: 0.0946
# Epoch 259/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 260/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9617 - val_accuracy: 0.0946
# Epoch 261/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 262/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 263/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 264/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 265/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9630 - val_accuracy: 0.0946
# Epoch 266/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9627 - val_accuracy: 0.0946
# Epoch 267/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9629 - val_accuracy: 0.0946
# Epoch 268/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9628 - val_accuracy: 0.0946
# Epoch 269/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9626 - val_accuracy: 0.0946
# Epoch 270/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9627 - val_accuracy: 0.0946
# Epoch 271/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9627 - val_accuracy: 0.0946
# Epoch 272/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9626 - val_accuracy: 0.0946
# Epoch 273/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9619 - val_accuracy: 0.0946
# Epoch 274/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9617 - val_accuracy: 0.0946
# Epoch 275/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9619 - val_accuracy: 0.0946
# Epoch 276/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9622 - val_accuracy: 0.0946
# Epoch 277/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9621 - val_accuracy: 0.0946
# Epoch 278/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 279/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9619 - val_accuracy: 0.0946
# Epoch 280/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9622 - val_accuracy: 0.0946
# Epoch 281/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 282/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 283/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 284/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9625 - val_accuracy: 0.0946
# Epoch 285/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9622 - val_accuracy: 0.0946
# Epoch 286/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9623 - val_accuracy: 0.0946
# Epoch 287/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9622 - val_accuracy: 0.0946
# Epoch 288/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9620 - val_accuracy: 0.0946
# Epoch 289/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9619 - val_accuracy: 0.0946
# Epoch 290/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9619 - val_accuracy: 0.0946
# Epoch 291/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9620 - val_accuracy: 0.0946
# Epoch 292/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9615 - val_accuracy: 0.0946
# Epoch 293/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9622 - val_accuracy: 0.0946
# Epoch 294/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9621 - val_accuracy: 0.0946
# Epoch 295/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9618 - val_accuracy: 0.0946
# Epoch 296/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9616 - val_accuracy: 0.0946
# Epoch 297/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9622 - val_accuracy: 0.0946
# Epoch 298/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9448 - accuracy: 0.1514 - val_loss: 1.9618 - val_accuracy: 0.0946
# Epoch 299/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9450 - accuracy: 0.1514 - val_loss: 1.9614 - val_accuracy: 0.0946
# Epoch 300/300
# 60/60 [==============================] - 0s 5ms/step - loss: 1.9449 - accuracy: 0.1514 - val_loss: 1.9618 - val_accuracy: 0.0946

# %%
#Model Save
model.save_weights('model_weights.h5')
model.save('model_keras.h5')

# %%
# visualizing losses and accuracy
# %matplotlib inline

train_loss=hist.history['loss']
val_loss=hist.history['val_loss']
train_acc=hist.history['accuracy']
val_acc=hist.history['val_accuracy']

epochs = range(len(train_acc))

plt.plot(epochs,train_loss,'r', label='train_loss')
plt.plot(epochs,val_loss,'b', label='val_loss')
plt.title('train_loss vs val_loss')
plt.legend()
plt.figure()

plt.plot(epochs,train_acc,'r', label='train_acc')
plt.plot(epochs,val_acc,'b', label='val_acc')
plt.title('train_acc vs val_acc')
plt.legend()
plt.figure()

# %%
def getLabel(id): 
    return id

# %%
# Evaluating the model
score = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss:', score[0])
print('Test accuracy:', score[1])

test_image = X_test[0:1]
print (test_image.shape)

print(model.predict(test_image))
#print(model.predict_classes(test_image))
print(y_test[0:1])

res = model.predict(X_test[:9])
plt.figure(figsize=(10, 10))

for i in range(0, 9):
    plt.subplot(330 + 1 + i)
    plt.imshow(X_test[i],cmap=plt.get_cmap('gray'))
    plt.gca().get_xaxis().set_ticks([])
    plt.gca().get_yaxis().set_ticks([])
    plt.ylabel('prediction ')
# show the plot
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Test Loss: 1.9617778062820435
# Test accuracy: 0.09459459781646729
# (1, 128, 128, 3)
# [[0.14881605 0.13978891 0.14670922 0.12832446 0.1437263  0.15133192
#   0.14130318]]
# [[0. 0. 1. 0. 0. 0. 0.]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# from sklearn.metrics import confusion_matrix
# results = model.predict(X_test)
# cm = confusion_matrix(np.where(y_test == 1)[1], results)
# plt.matshow(cm)
# plt.title('Confusion Matrix')
# plt.colorbar()
# plt.ylabel('True Label')
# plt.xlabel('Predicted Label')
# plt.show()

# %%
testimg_data_list=[]
test_img=cv2.imread('KDEF/M11AF.jpg')
    
test_img_resize=cv2.resize(test_img,(128,128))
testimg_data_list.append(test_img_resize)
testimg_data = np.array(testimg_data_list)
testimg_data = testimg_data.astype('float32')
testimg_data = testimg_data/255
testimg_data.shape

print("test image original shaape",testimg_data[0].shape)
print("image original shaape",test_img[0].shape)

results = model.predict(testimg_data)
plt.imshow(test_img,cmap=plt.get_cmap('Set2'))
plt.gca().get_xaxis().set_ticks([])
plt.gca().get_yaxis().set_ticks([])
plt.xlabel('prediction = %s' % getLabel(results[0]), fontsize=25)
# Out:
# test image original shaape (128, 128, 3)
# image original shaape (326, 3)
# Text(0.5, 0, 'prediction = [0.14885668 0.13982037 0.14672884 0.12823448 0.14373656 0.15128826\n 0.14133482]')
